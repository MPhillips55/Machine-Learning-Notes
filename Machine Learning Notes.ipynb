# %% [markdown]
# ## Machine Learning Notes - Regression
#
# you have some x's and y's and then use x to predict y

# %%
from IPython.display import Image

# %% [markdown]
# Some forms of bias: selection bias, publication bias, non-response bias, length bias

# %%
Image("capture.png")

# %%
Image("capture1.png")

# %%
Image("capture2.png")

# %% [markdown]
# ## Classification

# %%
Image("capture3.png")

# %%
Image("capture4.png")

# %%
Image("capture5.png")

# %%
Image("capture6.png")

# %% [markdown]
# # SVM and Trees

# %%
Image("capture7.png")

# %%
Image("capture8.png")

# %%
Image("capture8.png")

# %%
Image("capture9.png")

# %%
Image("capture12.png")

# %%
Image("capture13.png")

# %%
Image("capture14.png")

# %% [markdown]
# # Ensemble Methods

# %%
Image("capture10.png")

# %%
Image("capture11.png")

# %%
Image("capture15.png")

# %%
Image("capture16.png")

# %% [markdown]
# bagging is bootstrapping with replacement

# %% [markdown]
# boosting - samples depend on each other

# %%
Image("capture17.png")

# %%
Image("capture18.png")

# %% [markdown]
# adaboost - one of the most useful boosting methods

# %% [markdown]
# # Bayesian Methods and Text Data

# %%
Image("capture19.png")

# %%
Image("capture20.png")

# %%
Image("capture21.png")

# %%
Image("capture22.png")

# %%
Image("capture23.png")

# %%
Image("capture24.png")

# %%
Image("capture25.png")
